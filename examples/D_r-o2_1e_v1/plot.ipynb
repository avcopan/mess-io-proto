# %%
from pathlib import Path

import pyparsing as pp

mess_inp_file = Path("01_1-30_mess.inp")
spc_file = Path("species.csv")

# %%
from mess_io_proto import surface

surf = surface.from_mess(mess_inp_file, spc_inp=spc_file)
surf = surface.with_energies_relative_to(surf, 23)
surf = surface.without_fake_wells(surf)
# surface.display_network(surf)

# %%
from matplotlib import pyplot

size = (10, 5)
fig = pyplot.figure(figsize=size)
fig = pyplot.figure()


class Color:
    black = "#000000"
    red = "#FF2E2EFF"
    blue = "#4D4DFFFF"
    green = "#31FF31FF"


paths, colors = zip(
    ([23, 11, 1, 19], Color.black),
    ([22, 0, 1, 19], Color.black),
    ([22, 0, 4, 19], Color.black),
    ([23, 11, 18], Color.blue),
    ([23, 11, 1, 18], Color.green),
    strict=True,
)

fig = surface.plot_paths(
    surf,
    paths=paths,
    fig=fig,
    colors=colors,
    stereo=True,
)

# pyplot.savefig("plot.svg")
# Out:
# keys = [23, 11, frozenset({1, 11}), 1, frozenset({1, 19}), 19]
# feats = [NMolWell(energy=0.0, fake=False, id=23, type='nmol', names=['C5H7(504)', 'O2(6)'], interacting=False), UnimolWell(energy=-31.080000000000002, fake=False, id=11, type='unimol', name='S(602)'), Barrier(energy=-1.5300000000000011, fake=False, well_ids=(1, 11), name='ts_1_13', barrierless=False), UnimolWell(energy=-29.93, fake=False, id=1, type='unimol', name='S(1210)r0'), Barrier(energy=-10.850000000000001, fake=False, well_ids=(1, 19), name='ts_1_20', barrierless=False), NMolWell(energy=-31.47, fake=False, id=19, type='nmol', names=['OH(4)', 'S(1288)rs0'], interacting=False)]
# coords = [-1.0, 2.0, 2.5, 3.0, 3.5, 4.0]
# keys = [22, 0, frozenset({0, 1}), 1]
# feats = [NMolWell(energy=-11.82, fake=False, id=22, type='nmol', names=['C5H7(500)', 'O2(6)'], interacting=False), UnimolWell(energy=-30.39, fake=False, id=0, type='unimol', name='S(1206)r0'), Barrier(energy=-1.0199999999999996, fake=False, well_ids=(0, 1), name='ts_1_1', barrierless=False), UnimolWell(energy=-29.93, fake=False, id=1, type='unimol', name='S(1210)r0')]
# coords = [-1.0, 0.0, 1.5, 3.0]
# keys = [0, frozenset({0, 4}), 4, frozenset({19, 4}), 19]
# feats = [UnimolWell(energy=-30.39, fake=False, id=0, type='unimol', name='S(1206)r0'), Barrier(energy=4.359999999999999, fake=False, well_ids=(0, 4), name='ts_1_6', barrierless=False), UnimolWell(energy=-17.68, fake=False, id=4, type='unimol', name='S(1209)r0'), Barrier(energy=-2.030000000000001, fake=False, well_ids=(4, 19), name='ts_1_17', barrierless=False), NMolWell(energy=-31.47, fake=False, id=19, type='nmol', names=['OH(4)', 'S(1288)rs0'], interacting=False)]
# coords = [0.0, 0.5, 1.0, 2.5, 4.0]
# keys = [11, frozenset({18, 11}), 18]
# feats = [UnimolWell(energy=-31.080000000000002, fake=False, id=11, type='unimol', name='S(602)'), Barrier(energy=-2.9299999999999997, fake=False, well_ids=(11, 18), name='ts_1_23', barrierless=False), NMolWell(energy=-15.46, fake=False, id=18, type='nmol', names=['C5H6(478)', 'HO2(8)'], interacting=False)]
# coords = [2.0, 3.0, 4.0]
# keys = [1, frozenset({1, 18}), 18]
# feats = [UnimolWell(energy=-29.93, fake=False, id=1, type='unimol', name='S(1210)r0'), Barrier(energy=-8.629999999999999, fake=False, well_ids=(1, 18), name='ts_1_26', barrierless=False), NMolWell(energy=-15.46, fake=False, id=18, type='nmol', names=['C5H6(478)', 'HO2(8)'], interacting=False)]
# coords = [3.0, 3.5, 4.0]
# coord1, coord2 3.0 3.5
# feat1, feat2 energy=-29.93 fake=False id=1 type='unimol' name='S(1210)r0' energy=-8.629999999999999 fake=False well_ids=(1, 18) name='ts_1_26' barrierless=False
# coord1, coord2 3.5 4.0
# feat1, feat2 energy=-8.629999999999999 fake=False well_ids=(1, 18) name='ts_1_26' barrierless=False energy=-15.46 fake=False id=18 type='nmol' names=['C5H6(478)', 'HO2(8)'] interacting=False
# coord1, coord2 2.0 3.0
# feat1, feat2 energy=-31.080000000000002 fake=False id=11 type='unimol' name='S(602)' energy=-2.9299999999999997 fake=False well_ids=(11, 18) name='ts_1_23' barrierless=False
# coord1, coord2 3.0 4.0
# feat1, feat2 energy=-2.9299999999999997 fake=False well_ids=(11, 18) name='ts_1_23' barrierless=False energy=-15.46 fake=False id=18 type='nmol' names=['C5H6(478)', 'HO2(8)'] interacting=False
# coord1, coord2 0.0 0.5
# feat1, feat2 energy=-30.39 fake=False id=0 type='unimol' name='S(1206)r0' energy=4.359999999999999 fake=False well_ids=(0, 4) name='ts_1_6' barrierless=False
# coord1, coord2 0.5 1.0
# feat1, feat2 energy=4.359999999999999 fake=False well_ids=(0, 4) name='ts_1_6' barrierless=False energy=-17.68 fake=False id=4 type='unimol' name='S(1209)r0'
# coord1, coord2 1.0 2.5
# feat1, feat2 energy=-17.68 fake=False id=4 type='unimol' name='S(1209)r0' energy=-2.030000000000001 fake=False well_ids=(4, 19) name='ts_1_17' barrierless=False
# coord1, coord2 2.5 4.0
# feat1, feat2 energy=-2.030000000000001 fake=False well_ids=(4, 19) name='ts_1_17' barrierless=False energy=-31.47 fake=False id=19 type='nmol' names=['OH(4)', 'S(1288)rs0'] interacting=False
# coord1, coord2 -1.0 0.0
# feat1, feat2 energy=-11.82 fake=False id=22 type='nmol' names=['C5H7(500)', 'O2(6)'] interacting=False energy=-30.39 fake=False id=0 type='unimol' name='S(1206)r0'
# coord1, coord2 0.0 1.5
# feat1, feat2 energy=-30.39 fake=False id=0 type='unimol' name='S(1206)r0' energy=-1.0199999999999996 fake=False well_ids=(0, 1) name='ts_1_1' barrierless=False
# coord1, coord2 1.5 3.0
# feat1, feat2 energy=-1.0199999999999996 fake=False well_ids=(0, 1) name='ts_1_1' barrierless=False energy=-29.93 fake=False id=1 type='unimol' name='S(1210)r0'
# coord1, coord2 -1.0 2.0
# feat1, feat2 energy=0.0 fake=False id=23 type='nmol' names=['C5H7(504)', 'O2(6)'] interacting=False energy=-31.080000000000002 fake=False id=11 type='unimol' name='S(602)'
# coord1, coord2 2.0 2.5
# feat1, feat2 energy=-31.080000000000002 fake=False id=11 type='unimol' name='S(602)' energy=-1.5300000000000011 fake=False well_ids=(1, 11) name='ts_1_13' barrierless=False
# coord1, coord2 2.5 3.0
# feat1, feat2 energy=-1.5300000000000011 fake=False well_ids=(1, 11) name='ts_1_13' barrierless=False energy=-29.93 fake=False id=1 type='unimol' name='S(1210)r0'
# coord1, coord2 3.0 3.5
# feat1, feat2 energy=-29.93 fake=False id=1 type='unimol' name='S(1210)r0' energy=-10.850000000000001 fake=False well_ids=(1, 19) name='ts_1_20' barrierless=False
# coord1, coord2 3.5 4.0
# feat1, feat2 energy=-10.850000000000001 fake=False well_ids=(1, 19) name='ts_1_20' barrierless=False energy=-31.47 fake=False id=19 type='nmol' names=['OH(4)', 'S(1288)rs0'] interacting=False

# %%
# path0 = surface.path_from_well_id_sequence(surf, [28, 0, 1, 22])
# path1 = surface.path_from_well_id_sequence(surf, [28, 0, 21])
# path1

# %%
# from importlib import reload

# from matplotlib import pyplot

# reload(surface)


# size = (10, 5)
# fig = pyplot.figure(figsize=size)
# fig = pyplot.figure()

# data0 = list(enumerate(path0))
# data1 = list(enumerate(path1))
# fig = surface.plot_path_data(data0, fig=fig, amchi_mapping=surf.amchi_mapping)
# fig = surface.plot_path_data(
#     data1, fig=fig, amchi_mapping=surf.amchi_mapping, color="red"
# )
